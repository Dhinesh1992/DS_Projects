# %%
# importing required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('BreastCancer.csv')
df.shape
# Out:
# (569, 33)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Checking the datatypes of features
df.dtypes  # Except diagnosis(Target) column all are numerical columns
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# Checking for missing values
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(),cbar=None)
# Out:
# <AxesSubplot:>

# %%
# all the values from 'Unnamed: 32' has null values and 'id' column has unique entries. Hence we can drop those columns
df.drop(['id','Unnamed: 32'],axis=1,inplace=True)
df.dtypes
# Out:
# diagnosis                    int32
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
# Converting the object column into integer
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
# We can convert 'M' -> 1 and 'B' ->0
df['diagnosis']=np.where(df['diagnosis']=='M',1,0)
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
for i in df.drop('diagnosis',axis=1).columns:
    sns.distplot(df[i],hist=False)
    plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### From the above diagram it is seen that all the columns almost follow normal distribution

# %%
#Splitting the i/p and o/p features
X = df.drop('diagnosis',axis=1)
y = df['diagnosis'].copy()

# %%
plt.figure(figsize=(30,27))
sns.heatmap(X.corr(),annot=True)
plt.show()

# %% [markdown]
# ###### from the above plot, it is understood that there are many features that are highly correlated with each other. Hence we can remove one of the features from the highly correlated features

# %% [markdown]
# ### Feature Selection

# %%
def corr_features(df):
    df_corr = df.corr()
    df_cols = df_corr.columns
    corr_cols =set()
    for i in range(len(df_cols)):
        for j in range(i):
            if abs(df_corr.iloc[i,j]) >=0.5 and df_cols[i] not in corr_cols and df_cols[i] != df_cols[j]:
                corr_cols.add(df_cols[i])
    return corr_cols

# %%
X1 = X.drop(list(corr_features(X)),axis=1).copy()

# %%
X1.head()
# Out:
#    radius_mean  texture_mean  smoothness_mean  texture_se  smoothness_se  \
# 0        17.99         10.38          0.11840      0.9053       0.006399
# 1        20.57         17.77          0.08474      0.7339       0.005225
# 2        19.69         21.25          0.10960      0.7869       0.006150
# 3        11.42         20.38          0.14250      1.1560       0.009110
# 4        20.29         14.34          0.10030      0.7813       0.011490
#
#    symmetry_se
# 0      0.03003
# 1      0.01389
# 2      0.02250
# 3      0.05963
# 4      0.01756

# %% [markdown]
# ### Importing the required models for classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

# %%
# Splitting train and test data
X_train,X_test,y_train,y_test = train_test_split(X1,y,test_size=0.3,random_state=101)

# %%
# Initializing the classification models
lr = LogisticRegression()
dt = DecisionTreeClassifier(ccp_alpha=0.0)
knn = KNeighborsClassifier(n_neighbors=5)
sv = SVC()
nb = MultinomialNB()

# %%
models = [lr,dt,knn,sv,nb]
scores = []
for i in models:
    scr = cross_val_score(i,X_train,y_train,cv=5)
    scores.append(np.mean(scr))

plt.figure(figsize=(10,6))
plt.plot([str(i) for i in models],scores,'r-',marker='o')
plt.xticks(rotation=90)
plt.text(0.0,scores[0]+0.005,'LR')
plt.text(1,scores[1]+.005,'DT')
plt.text(2,scores[2]+.005,'KNN')
plt.text(3,scores[3]+.005,'SVC')
plt.text(4,scores[4]+.005,'MultinomialNB')
plt.show()

# %% [markdown]
# ### From the above diagram it's clear that SVC shows highest training score

# %%
sv.fit(X_train,y_train)
y_pred = sv.predict(X_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.8771929824561403

# %%
dt.fit(X_train,y_train)
y_pred1 = dt.predict(X_test)

accuracy_score(y_test,y_pred1)
# Out:
# 0.8596491228070176

# %%
lr.fit(X_train,y_train)
y_pred2 = lr.predict(X_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.8771929824561403

# %% [markdown]
# ### Checking the accuracy when all the features are considered for model building

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X,y,test_size=0.3,random_state=40)

# %%
sc = cross_val_score(sv,X1_train,y1_train,scoring='accuracy',cv=5)
np.mean(sc)
# Out:
# 0.9069620253164556

# %%
sv.fit(X1_train,y1_train)
y_p = sv.predict(X1_test)

accuracy_score(y1_test,y_p)
# Out:
# 0.9298245614035088

# %%
confusion_matrix(y1_test,y_p)
# Out:
# array([[112,   3],
#        [  9,  47]], dtype=int64)

# %%
print(classification_report(y1_test,y_p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       115
#            1       0.94      0.84      0.89        56
#
#     accuracy                           0.93       171
#    macro avg       0.93      0.91      0.92       171
# weighted avg       0.93      0.93      0.93       171
